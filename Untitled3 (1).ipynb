# %%
from IPython.display import Image, display
display(Image(filename="KMeans_choropleth.png"))

# %%
from IPython.display import Image, display
display(Image(filename="HierarchicalClustering_choropleth.png"))

# %%
from IPython.display import Image, display
display(Image(filename="DBSCAN_choropleth.png"))

# %%
from IPython.display import Image, display
display(Image(filename="HDBSCAN_choropleth.png"))
